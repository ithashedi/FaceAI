# %%
import numpay as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c4b936684574> in <module>
# ----> 1 import numpay as np
#
# ModuleNotFoundError: No module named 'numpay'

# %%
import numpy as np

# %%
import PIL

# %%
import cv2
import mtpoltlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-ee6df13cd7c3> in <module>
#       1 import cv2
# ----> 2 import mtpoltlib
#
# ModuleNotFoundError: No module named 'mtpoltlib'

# %%
import cv2

# %%
import mtpoltlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-7e18853f7280> in <module>
# ----> 1 import mtpoltlib
#
# ModuleNotFoundError: No module named 'mtpoltlib'

# %%
import matpoltlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-f71547b92078> in <module>
# ----> 1 import matpoltlib
#
# ModuleNotFoundError: No module named 'matpoltlib'

# %%
import matplotlib

# %%
#reading an image using PIL
img = Image.open('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b97d3884138f> in <module>
#       1 #reading an image using PIL
# ----> 2 img = Image.open('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment')
#
# NameError: name 'Image' is not defined

# %%
img = Image.open('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0236e8a4642f> in <module>
# ----> 1 img = Image.open('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
#
# NameError: name 'Image' is not defined

# %%
img = image.open ('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bb4d858d264b> in <module>
# ----> 1 img = image.open ('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
#
# NameError: name 'image' is not defined

# %%
from PIL import Image

# %%
img = Image.open('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=948x1025 at 0x235E4D677C0>

# %%
img_cv2 = cv2.imread('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
img_cv2 ## reading the image using cv2
# Out:
# array([[[ 61,  53,  53],
#         [255, 252, 251],
#         [255, 255, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 61,  53,  53],
#         [255, 252, 251],
#         [255, 255, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 61,  53,  53],
#         [255, 252, 251],
#         [255, 255, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[109, 109, 109],
#         [237, 237, 237],
#         [242, 242, 242],
#         ...,
#         [239, 239, 239],
#         [233, 233, 233],
#         [236, 236, 236]],
#
#        [[109, 109, 109],
#         [237, 237, 237],
#         [242, 242, 242],
#         ...,
#         [241, 241, 241],
#         [242, 242, 242],
#         [241, 241, 241]],
#
#        [[108, 108, 108],
#         [108, 108, 108],
#         [108, 108, 108],
# ...

# %%
img_cv2.shape
# Out:
# (1025, 948, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ddf8c40a318d> in <module>
# ----> 1 plt.imshow('V:/OneDrive - Leeds Trinity University/Storage/BSc in computing/Semster One Assignments and projects/Machine Learning/1 creating vertual environment.jpg')
#
# V:\Anaconda32020\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ...
